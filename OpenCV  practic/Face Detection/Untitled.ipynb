# %%
import cv2

# %%
img=cv2.imread('Wildlife_at_Maasai_Mara_(Lion).jpg')

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newimg)

# %%
print(img)
# Out:
# [[[130 191 217]
#   [138 199 225]
#   [140 201 227]
#   ...
#   [170 195 211]
#   [217 249 255]
#   [215 247 255]]
#
#  [[133 197 222]
#   [137 201 226]
#   [134 198 223]
#   ...
#   [209 234 250]
#   [212 244 255]
#   [212 244 255]]
#
#  [[136 203 228]
#   [135 202 227]
#   [129 196 221]
#   ...
#   [206 231 247]
#   [207 238 253]
#   [209 240 255]]
#
#  ...
#
#  [[106 170 204]
#   [106 170 204]
#   [105 168 202]
#   ...
#   [119 255 255]
#   [132 242 254]
#   [137 245 255]]
#
#  [[103 165 201]
#   [101 163 199]
#   [100 162 198]
#   ...
#   [106 242 254]
#   [140 242 254]
#   [140 242 254]]
#
#  [[103 165 201]
#   [101 163 199]
#   [100 162 198]
#   ...
#   [110 248 255]
#   [140 242 254]
#   [140 242 254]]]

# %%
import cv2
from matplotlib import pyplot as plt

cap=cv2.VideoCapture(0)
while True:
      ret,frame=cap.read()
      gray_frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        
      if ret==False:  
          continue
      cv2.imshow("video Frame",frame)
      key_pressed=cv2.waitKey(1)& 0xFF
      if key_pressed==ord('q'):
         break
            
cap.realease()
cv2.destroyALlWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\RAUSHA~1\AppData\Local\Temp/ipykernel_9988/2148630075.py in <module>
#       7           continue
#       8       cv2.imshow("video Frame",frame)
# ----> 9       key_pressed=cv2.waitKey(1)& 0xFF
#      10       if key_pressed==ord('q'):
#      11          break
#
# KeyboardInterrupt:
